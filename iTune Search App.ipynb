# %%
import requests
import json

# %%
base_site = "https://itunes.apple.com/search"

# %%
url = base_site + "?term=the+beatles&country=us"

print(url)

requests.get(url)
# Out:
# https://itunes.apple.com/search?term=the+beatles&country=us
# <Response [200]>

# %%
response = requests.get(base_site, params= {"term": "the beatles", "country": "us", "limit":200})

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'https://itunes.apple.com/search?term=the+beatles&country=us&limit=200'

# %%
info = response.json()
print(json.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 200,
#     "results": [
#         {
#             "wrapperType": "track",
#             "kind": "music-video",
#             "artistId": 136975,
#             "collectionId": 1441133180,
#             "trackId": 1441134703,
#             "artistName": "The Beatles",
#             "collectionName": "The Beatles (The White Album)",
#             "trackName": "The Beatles",
#             "collectionCensoredName": "The Beatles (The White Album)",
#             "trackCensoredName": "The Beatles (Documentary)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/music-video/the-beatles-documentary/1441134703?uo=4",
#             "trackViewUrl": "https://music.apple.com/us/music-video/the-beatles-documentary/1441134703?uo=4",
# ...

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
print(json.dumps(info['results'][0], indent=4))
# Out:
# {
#     "wrapperType": "track",
#     "kind": "music-video",
#     "artistId": 136975,
#     "collectionId": 1441133180,
#     "trackId": 1441134703,
#     "artistName": "The Beatles",
#     "collectionName": "The Beatles (The White Album)",
#     "trackName": "The Beatles",
#     "collectionCensoredName": "The Beatles (The White Album)",
#     "trackCensoredName": "The Beatles (Documentary)",
#     "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#     "collectionViewUrl": "https://music.apple.com/us/music-video/the-beatles-documentary/1441134703?uo=4",
#     "trackViewUrl": "https://music.apple.com/us/music-video/the-beatles-documentary/1441134703?uo=4",
#     "previewUrl": "https://video-ssl.itunes.apple.com/itunes-assets/Video128/v4/32/a2/13/32a21383-7e17-e8ae-e0e0-bf6b78144fc0/mzvf_7037047804382233330.640x478.h264lc.U.p.m4v",
# ...

# %%
response.json()["resultCount"]
# Out:
# 200

# %%
dir(requests)
# Out:
# ['ConnectTimeout',
#  'ConnectionError',
#  'DependencyWarning',
#  'FileModeWarning',
#  'HTTPError',
#  'NullHandler',
#  'PreparedRequest',
#  'ReadTimeout',
#  'Request',
#  'RequestException',
#  'RequestsDependencyWarning',
#  'Response',
#  'Session',
#  'Timeout',
#  'TooManyRedirects',
#  'URLRequired',
#  '__author__',
#  '__author_email__',
#  '__build__',
#  '__builtins__',
#  '__cached__',
#  '__cake__',
#  '__copyright__',
#  '__description__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__url__',
#  '__version__',
#  '_check_cryptography',
#  '_internal_utils',
#  'adapters',
#  'api',
#  'auth',
#  'certs',
#  'chardet',
#  'check_compatibility',
#  'codes',
#  'compat',
#  'cookies',
#  'delete',
#  'exceptions',
#  'get',
#  'head',
#  'hooks',
#  'logging',
#  'models',
#  'options',
#  'packages',
#  'patch',
#  'post',
#  'put',
#  'request',
#  'session',
# ...

# %%
import pandas as pd

# %%
song_df = pd.DataFrame(info["results"])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-384425827cf4> in <module>
#       1 song_df = pd.DataFrame(info["results"])
# ----> 2 df
#
# NameError: name 'df' is not defined

# %%
info = response.json()

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
song_df = pd.DataFrame(info["results"])
song_df
# Out:
#     wrapperType         kind  artistId  collectionId       trackId  \
# 0         track  music-video  136975.0  1.441133e+09  1.441135e+09
# 1         track  music-video  136975.0  1.441165e+09  1.441165e+09
# 2         track  music-video  136975.0  1.441164e+09  1.441165e+09
# 3         track  music-video  136975.0  1.441165e+09  1.441165e+09
# 4         track  music-video  136975.0  1.441163e+09  1.441164e+09
# ..          ...          ...       ...           ...           ...
# 195       track         song  136975.0  1.441133e+09  1.441133e+09
# 196       track         song  136975.0  1.441165e+09  1.441165e+09
# 197       track         song  136975.0  1.441133e+09  1.441134e+09
# 198       track         song  136975.0  1.441133e+09  1.441134e+09
# 199       track         song  136975.0  1.441133e+09  1.441134e+09
#
#       artistName                          collectionName  \
# 0    The Beatles           The Beatles (The White Album)
# ...

# %%
github_base_site= "https://jobs.github.com/positions.json"

# %%
github_request = requests.get(github_base_site, params= {"description": "data engineer","location":"los angeles" })

# %%
github_request.status_code
# Out:
# 200

# %%
github_request.ok
# Out:
# True

# %%
collected_info= github_request.json()

# %%
len(collected_info)
# Out:
# 3

# %%
github_request = requests.get(github_base_site)

# %%
values = github_request.json()
values
# Out:
# [{'id': '0f48aadd-549a-4d74-a461-d889342de1aa',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/0f48aadd-549a-4d74-a461-d889342de1aa',
#   'created_at': 'Thu Dec 31 18:49:26 UTC 2020',
#   'company': 'Benco Dental',
#   'company_url': 'http://www.benco.com',
#   'location': 'Nationwide/Remote',
#   'title': 'Software Developer - Full Stack',
# ...

# %%
githubjobs=pd.DataFrame(values)
githubjobs.shape
# Out:
# (50, 11)

# %%
githubjobs.to_csv("Githubjobs1.csv")
